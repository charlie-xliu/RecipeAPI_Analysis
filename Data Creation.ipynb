# %%
import pandas as pd
import requests

# %%
api_key = 'c77048acd3a244319f5814fa3c4a407d'
api_key1 = '56bde638323c4f54adbc1366359180c8'
api_key2 = '7003ea450e6c43078b66c851a065629e'
rec_id = '1'

# %%
data = []
for i in range (5650 ,6000):
  response = requests.get(f'https://api.spoonacular.com/recipes/{i}/information?apiKey={api_key}&includeNutrition=true')
  recipe = response.json()

  name = recipe.get('title')
  servings = recipe.get('servings')
  cookTime = recipe.get('readyInMinutes')
  link = recipe.get('sourceUrl')
  vegetarian = recipe.get('vegetarian')
  vegan = recipe.get('vegan')
  glutenFree = recipe.get('glutenFree')
  dairyFree = recipe.get('dairyFree')
  ingredients = recipe.get('extendedIngredients')
  cuisines = recipe.get('cuisines')
  dishTypes = recipe.get('dishTypes')
  diets = recipe.get('diets')
  score = recipe.get('spoonacularScore')

  d = {'name' : name,
       'servings' : servings,
       'cookTime' : cookTime,
       'link' : link,
       'vegetarian' : vegetarian,
       'vegan' : vegan,
       'glutenFree' : glutenFree,
       'dairyFree' : dairyFree,
       'ingredients' : ingredients, 
       'cuisines' : cuisines,
       'dishTypes' : dishTypes,
       'diets' : diets,
       'score' : score}
  data.append(d)

df = pd.DataFrame(data)
df
# Out:
#                           name  servings  cookTime  \
# 0             Shrimp and Grits       2.0       5.0
# 1    Shrimp with Romesco Sauce       6.0      10.0
# 2             Shrimp And Grits       1.0      35.0
# 3                         None       NaN       NaN
# 4                  Shrimp Roll       1.0      15.0
# ..                         ...       ...       ...
# 345                       None       NaN       NaN
# 346                       None       NaN       NaN
# 347                       None       NaN       NaN
# 348                       None       NaN       NaN
# 349                       None       NaN       NaN
#
#                                                   link vegetarian  vegan  \
# 0    http://cookingwithmichele.com/2009/03/shrimp-g...      False  False
# 1    http://cookingwithmichele.com/2009/07/shrimp-w...      False  False
# 2    http://recipes.prevention.com/Recipe/shrimp-an...      False  False
# ...

# %%
len(df[df['score'].isna() == True])
# Out:
# 213

# %%
df.dropna()
# Out:
#                                                   name  servings  cookTime  \
# 0                                     Shrimp and Grits       2.0       5.0
# 1                            Shrimp with Romesco Sauce       6.0      10.0
# 2                                     Shrimp And Grits       1.0      35.0
# 4                                          Shrimp Roll       1.0      15.0
# 5                                Shrimp Scampi For Two      30.0      19.0
# ..                                                 ...       ...       ...
# 177  Lowcountry Shrimp and Grits with Vidalia Musta...       6.0      45.0
# 178       Grilled Jumbo Shrimp with Garlic-Herb Butter       4.0      30.0
# 179          Grilled Shrimp with Fresh Cranberry Salsa       4.0      74.0
# 180                                    Amaretto Shrimp       2.0      20.0
# 181                                 Spicy Cajun Shrimp       4.0      30.0
#
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                                                   name  servings  cookTime  \
# 0                                     Shrimp and Grits       2.0       5.0
# 1                            Shrimp with Romesco Sauce       6.0      10.0
# 2                                     Shrimp And Grits       1.0      35.0
# 4                                          Shrimp Roll       1.0      15.0
# 5                                Shrimp Scampi For Two      30.0      19.0
# ..                                                 ...       ...       ...
# 177  Lowcountry Shrimp and Grits with Vidalia Musta...       6.0      45.0
# 178       Grilled Jumbo Shrimp with Garlic-Herb Butter       4.0      30.0
# 179          Grilled Shrimp with Fresh Cranberry Salsa       4.0      74.0
# 180                                    Amaretto Shrimp       2.0      20.0
# 181                                 Spicy Cajun Shrimp       4.0      30.0
#
# ...

# %%
df = df.reset_index()

# %%
df_whole = pd.read_csv('big_data')

# %%
df = pd.read_csv('dataset1')
df1 = pd.read_csv('dataset2')
df2 = pd.read_csv('dataset3')
df4 = pd.read_csv('dataset5')
df5 = pd.read_csv('dataset6')
df6 = pd.read_csv('dataset6')
df7 = pd.read_csv('dataset8')
df8 = pd.read_csv('dataset9')
df9 = pd.read_csv('dataset10')
df10 = pd.read_csv('dataset11')
df11 = pd.read_csv('dataset12')
df12 = pd.read_csv('dataset13')
df13 = pd.read_csv('dataset14')
df14 = pd.read_csv('dataset15')
df15 = pd.read_csv('dataset16')

# %%
df_concat = pd.concat([df_whole,df])
len(df)
# Out:
# 136

# %%
df_concat.to_csv('big_data',index = False)

# %%
len(pd.read_csv('big_data'))
# Out:
# 1790

# %%
df[df['ingredients'].apply(lambda x: 'egg' in x)]
# Out:
#      index                                               name  servings  \
# 0        1                          Fried Anchovies with Sage       3.0
# 5        6                                    Fried Anchovies      15.0
# 11      13       Anchovies, Tomatoes And Green Beans Couscous       1.0
# 19      23                Cauliflower, Anchovies and Tomatoes       1.0
# 20      25            Anchovy Fries with Smoked Paprika Aioli       8.0
# 35      41             Anchovy & Italian Parsley Deviled Eggs       1.0
# 37      43    Pressed Summer Sandwich with Eggs and Anchovies      15.0
# 42      50         Hard-Cooked Eggs with Crisp Anchovy Crumbs      20.0
# 43      51  Acciughe Con Salsa Verde (anchovies In Green S...       8.0
# 44      52      California Artichokes With Anchovy Mayonnaise       4.0
# 55      65                                   Pasta Puttanesca       4.0
# 56      66                           Egg and Anchovy Crostini       8.0
# ...

# %%
df1 = pd.read_csv('rating1')
df2 = pd.read_csv('rating2')
df3 = pd.read_csv('rating3')
df4 = pd.read_csv('rating4')
df5 = pd.read_csv('rating5')
df6 = pd.read_csv('rating6')
df7 = pd.read_csv('rating7')
df8 = pd.read_csv('rating8')
df9 = pd.read_csv('rating9')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9])

# %%
df.rating.unique()
# Out:
# array([73, 67, 72, 83, 82, 37, 78, 87, 63, 23, 88, 92, 27, 12],
#       dtype=int64)

# %%
df[df.diets == '[\'gluten free\', \'dairy free\', \'lacto ovo vegetarian\', \'vegan\']']
# Out:
#      index                                               name  servings  \
# 114     31  Spicy Cucumber Salad With Ginger, Shallots, An...       1.0
# 113     96                              Smoky Tajín Margarita       1.0
#
#      cookTime                                               link  vegetarian  \
# 114      20.0  Spicy Cucumber Salad with Ginger, Shallots, an...        True
# 113       5.0  https://www.eatingwell.com/recipe/279665/smoky...        True
#
#      vegan  glutenFree  dairyFree  \
# 114   True        True       True
# 113   True        True       True
#
#                                            ingredients cuisines  \
# 114  [{'id': 10111205, 'aisle': 'Produce', 'image':...       []
# 113  [{'id': 10014412, 'aisle': 'Frozen', 'image': ...       []
#
#                  dishTypes                                              diets  \
# 114          ['side dish']  ['gluten free', 'dairy free', 'lacto ovo veget...
# ...

# %%
# Split into manageable parts so we are able to make pauses
df1 = df.iloc[0:200]
df2 = df.iloc[200:400]
df3 = df.iloc[400:600]
df4 = df.iloc[600:800]
df5 = df.iloc[800:1000]
df6 = df.iloc[1000:1200]
df7 = df.iloc[1200:1400]
df8 = df.iloc[1400:1600]
df9 = df.iloc[1600:1789]

# %%
import os
import google.generativeai as genai
import time

#gemini_api_key = 'AIzaSyD0L-YK5GGIz3vJw2e8qUidsu0yOUi5ou4'
#gemini_api_key = 'AIzaSyAmflp7JSK9VswKAgaI-gFdTUlhtKQLTaI'
gemini_api_key = 'AIzaSyDxGHNBjiaMlzUlEHoJy9OkbOawOZoSf8A'

genai.configure(api_key=gemini_api_key)
multimodal_model = genai.GenerativeModel("gemini-1.5-flash-002")

# %%
def getRating(ingredients, dishType, diets, dish):
  time.sleep(4)
  model_response = multimodal_model.generate_content(f"Rate this dish 1-100 with 1 being extremely unhealthy and 100 being the most healthy dish ever. Can you try to refrain from only using multiples of 5 in your judging and only give the number? Here's the name: {dish}, ingredients: {ingredients}, dish type: {dishType}, and diets it fulfills: {diets}")
  return model_response.text[:2]

# %%
df9['health_rating'] = df9.apply(lambda row: getRating(row['ingredients'], row['dishTypes'], row['diets'], row['name']), axis=1)

# %%
df9.to_csv('health9',index = False)

# %%
df1 = pd.read_csv('health1')
df2 = pd.read_csv('health2')
df3 = pd.read_csv('health3')
df4 = pd.read_csv('health4')
df5 = pd.read_csv('health5')
df6 = pd.read_csv('health6')
df7 = pd.read_csv('health7')
df8 = pd.read_csv('health8')
df9 = pd.read_csv('health9')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9])

# %%
df[df['health_rating'] == 23]
# Out:
#      index                                 name  servings  cookTime  \
# 143     13  The Chicken-fried Pork Belly Caesar       4.0      45.0
#
#                                                   link  vegetarian  vegan  \
# 143  http://ruhlman.com/2012/01/chicken-fried-pork-...       False  False
#
#      glutenFree  dairyFree                                        ingredients  \
# 143       False      False  [{'id': 15001, 'aisle': 'Seafood', 'image': 'a...
#
#     cuisines                                        dishTypes diets  \
# 143       []  ['lunch', 'main course', 'main dish', 'dinner']    []
#
#          score  health_rating
# 143  68.338791             23

# %%
df[df.pescatarian == True]
# Out:
#      index                                               name  servings  \
# 0        1                          Fried Anchovies with Sage       3.0
# 1        2   Anchovies Appetizer With Breadcrumbs & Scallions       8.0
# 2        3                 Carrots, Cauliflower And Anchovies       1.0
# 3        4  Bap Story: Stir Fried Anchovies (Myulchi Bokkeum)       2.0
# 4        5                        Bread, Butter And Anchovies       1.0
# ..     ...                                                ...       ...
# 183    220   Roasted Cauliflower with Capers and Bread Crumbs       6.0
# 184    223  Sautéed Red Cabbage With Onions, Garlic, And A...       1.0
# 185    226               Roasted Green Beans With Bagna Cauda       4.0
# 186    229   Romaine Salad with Anchovy Dressing and Parmesan       8.0
# 188    234                     Grilled Lettuces with Manchego       4.0
#
#      cookTime                                               link  vegetarian  \
# ...

# %%
df[df.rating == 67]
# Out:
#      index                                               name  servings  \
# 2        3                 Carrots, Cauliflower And Anchovies       1.0
# 145     16      Natural Factors’ Tropical Summer Caesar Salad       2.0
# 183     64                                Caesar Salad Spears      60.0
# 197     79                                      Protein Pesto       2.0
# 117    184                                  Salad Capricciosa       2.0
# 121    194                               Marinated Vegetables       4.0
# 1       70                                 Baked Gefilte Fish       1.0
# 55     145              Boston Bluefish With Spinach And Soup       1.0
# 172     28                                               Home       8.0
# 150     74                  Hungry Girl - Thursday Newsletter       2.0
# 122    118                            Halibut With Kiwi Salsa       2.0
# 88     203                                      Orange Roughy       1.0
# ...

# %%
ingredients = df[df.rating == 92].iloc[0,9]

# %%
dishType = df[df.rating == 92].iloc[0,11]

# %%
diets = df[df.rating == 92].iloc[0,12]

# %%
import os
import google.generativeai as genai
import time

#gemini_api_key = 'AIzaSyD0L-YK5GGIz3vJw2e8qUidsu0yOUi5ou4'
gemini_api_key = 'AIzaSyAmflp7JSK9VswKAgaI-gFdTUlhtKQLTaI'

genai.configure(api_key=gemini_api_key)
multimodal_model = genai.GenerativeModel("gemini-1.5-flash-002")

# %%
model_response = multimodal_model.generate_content(f"Rate this dish 1-100 with 1 being almost inedible and 100 being Gordon Ramseys new favorite dish. Can you try to refrain from only using multiples of 5? Here's the name: Miso Glazed Black Cod, ingredients: {ingredients}, dish type: {dishType}, and diets it fulfills: {diets}")
model_response.text
# Out:
# "I'd rate this Miso Glazed Black Cod a 92.  The ingredients suggest a dish with a good balance of sweet, savory, and umami flavors, and the black cod itself is a high-quality fish that lends itself well to this type of preparation.  The inclusion of sake and mirin hints at depth of flavor. The only thing holding it back from a perfect score is the lack of specifics in the recipe (e.g., baking time, temperature).  A perfectly executed version of this dish would be truly exceptional.\n"

# %%
orignal = pd.read_csv('big_data')
